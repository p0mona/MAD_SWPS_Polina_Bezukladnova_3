# %% [markdown]
# <a href="https://colab.research.google.com/github/p0mona/MAD_SWPS_Polina_Bezukladnova_3/blob/main/pandas_cw.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
apple: pd.DataFrame = pd.read_csv("/content/apple_quality.csv")

# %%
apple
# Out:
#         A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0        0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1        1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2        2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3        3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4        4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...      ...       ...       ...        ...          ...        ...       ...
# 3996  3996.0 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997  3997.0 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998  3998.0 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  3999.0  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
# 4000     NaN       NaN       NaN        NaN          NaN        NaN       NaN
#
# ...

# %%
apple.tail(n = 4)
# Out:
#         A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 3997  3997.0 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998  3998.0 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  3999.0  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
# 4000     NaN       NaN       NaN        NaN          NaN        NaN       NaN
#
#                                 Acidity Quality
# 3997                       -1.334611391     bad
# 3998                       -2.229719806    good
# 3999                        1.599796456    good
# 4000  Created_by_Nidula_Elgiriyewithana     NaN

# %%
apple.columns
# Out:
# Index(['A_id', 'Size', 'Weight', 'Sweetness', 'Crunchiness', 'Juiciness',
#        'Ripeness', 'Acidity', 'Quality'],
#       dtype='object')

# %%
apple.index
# Out:
# RangeIndex(start=0, stop=4001, step=1)

# %%
apple.dtypes
# Out:
# A_id           float64
# Size           float64
# Weight         float64
# Sweetness      float64
# Crunchiness    float64
# Juiciness      float64
# Ripeness       float64
# Acidity         object
# Quality         object
# dtype: object

# %%
apple.describe()
# Out:
#               A_id         Size       Weight    Sweetness  Crunchiness  \
# count  4000.000000  4000.000000  4000.000000  4000.000000  4000.000000
# mean   1999.500000    -0.503015    -0.989547    -0.470479     0.985478
# std    1154.844867     1.928059     1.602507     1.943441     1.402757
# min       0.000000    -7.151703    -7.149848    -6.894485    -6.055058
# 25%     999.750000    -1.816765    -2.011770    -1.738425     0.062764
# 50%    1999.500000    -0.513703    -0.984736    -0.504758     0.998249
# 75%    2999.250000     0.805526     0.030976     0.801922     1.894234
# max    3999.000000     6.406367     5.790714     6.374916     7.619852
#
#          Juiciness     Ripeness
# count  4000.000000  4000.000000
# mean      0.512118     0.498277
# std       1.930286     1.874427
# min      -5.961897    -5.864599
# 25%      -0.801286    -0.771677
# 50%       0.534219     0.503445
# 75%       1.835976     1.766212
# max       7.364403     7.237837

# %%
col: pd.Series = apple['Sweetness']
col
# Out:
# 0       5.346330
# 1       3.664059
# 2      -1.738429
# 3       1.324874
# 4      -0.384658
#           ...
# 3996   -0.204020
# 3997   -2.440461
# 3998    2.366397
# 3999    0.121217
# 4000         NaN
# Name: Sweetness, Length: 4001, dtype: float64

# %%
apple[['Sweetness', 'Crunchiness', 'Juiciness']].head()
# Out:
#    Sweetness  Crunchiness  Juiciness
# 0   5.346330    -1.012009   1.844900
# 1   3.664059     1.588232   0.853286
# 2  -1.738429    -0.342616   2.838636
# 3   1.324874    -0.097875   3.637970
# 4  -0.384658    -0.553006   3.030874

# %%
apple.select_dtypes(include=['object']).head()
# Out:
#         Acidity Quality
# 0  -0.491590483    good
# 1  -0.722809367    good
# 2   2.621636473     bad
# 3   0.790723217    good
# 4   0.501984036    good

# %%
apple.dtypes.value_counts()
# Out:
# float64    7
# object     2
# Name: count, dtype: int64

# %%
apple['Crunchiness'].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3996    False
# 3997    False
# 3998    False
# 3999    False
# 4000     True
# Name: Crunchiness, Length: 4001, dtype: bool

# %%
apple['Crunchiness'].isnull().any()
# Out:
# np.True_

# %%
apple['Weight'].fillna(0)
# Out:
# 0      -2.512336
# 1      -2.839257
# 2      -1.351282
# 3      -2.271627
# 4      -1.296612
#           ...
# 3996    1.949253
# 3997   -2.138247
# 3998   -1.779337
# 3999   -1.715505
# 4000    0.000000
# Name: Weight, Length: 4001, dtype: float64

# %%
apple.fillna({
    'Weight': 0.0,
    'Crunchiness': 0.0,
})
# Out:
#         A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0        0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1        1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2        2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3        3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4        4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...      ...       ...       ...        ...          ...        ...       ...
# 3996  3996.0 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997  3997.0 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998  3998.0 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  3999.0  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
# 4000     NaN       NaN  0.000000        NaN     0.000000        NaN       NaN
#
# ...

# %%
apple["Size"].head() + 3
# Out:
# 0   -0.970049
# 1    1.804783
# 2    2.707976
# 3    2.342804
# 4    4.364217
# Name: Size, dtype: float64

# %%
apple['Size'].head() > 0.5
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# Name: Size, dtype: bool

# %%
apple_new_idx: pd.DataFrame = apple.set_index('Size')
apple_new_idx
# Out:
#              A_id    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# Size
# -3.970049     0.0 -2.512336   5.346330    -1.012009   1.844900  0.329840
# -1.195217     1.0 -2.839257   3.664059     1.588232   0.853286  0.867530
# -0.292024     2.0 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# -0.657196     3.0 -2.271627   1.324874    -0.097875   3.637970 -3.413761
#  1.364217     4.0 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...           ...       ...        ...          ...        ...       ...
# -0.293118  3996.0  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# -2.634515  3997.0 -2.138247  -2.440461     0.657223   2.199709  4.763859
# -4.008004  3998.0 -1.779337   2.366397    -0.200329   2.161435  0.214488
#  0.278540  3999.0 -1.715505   0.121217    -1.154075   1.266677 -0.776571
#  NaN          NaN       NaN        NaN          NaN        NaN       NaN
#
#                                      Acidity Quality
# Size
# ...

# %%
apple_new_idx['test'] = 100
apple_new_idx.head()
# Out:
#            A_id    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# Size
# -3.970049   0.0 -2.512336   5.346330    -1.012009   1.844900  0.329840
# -1.195217   1.0 -2.839257   3.664059     1.588232   0.853286  0.867530
# -0.292024   2.0 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# -0.657196   3.0 -2.271627   1.324874    -0.097875   3.637970 -3.413761
#  1.364217   4.0 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
#
#                 Acidity Quality  test
# Size
# -3.970049  -0.491590483    good   100
# -1.195217  -0.722809367    good   100
# -0.292024   2.621636473     bad   100
# -0.657196   0.790723217    good   100
#  1.364217   0.501984036    good   100

# %%
del apple_new_idx['test']
apple_new_idx.head()
# Out:
#            A_id    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# Size
# -3.970049   0.0 -2.512336   5.346330    -1.012009   1.844900  0.329840
# -1.195217   1.0 -2.839257   3.664059     1.588232   0.853286  0.867530
# -0.292024   2.0 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# -0.657196   3.0 -2.271627   1.324874    -0.097875   3.637970 -3.413761
#  1.364217   4.0 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
#
#                 Acidity Quality
# Size
# -3.970049  -0.491590483    good
# -1.195217  -0.722809367    good
# -0.292024   2.621636473     bad
# -0.657196   0.790723217    good
#  1.364217   0.501984036    good
